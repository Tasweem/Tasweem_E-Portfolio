# %%
# calculate the Pearson's correlation between two variables
import pandas as pd
from numpy import mean
from numpy import std
from numpy import cov
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot as plt
import seaborn as sns

from scipy.stats import pearsonr

df = pd.read_csv("C:\\Users\\tasweemb\\Documents\\Machine Learning Module\\Datasets\\Auto\\auto-mpg.csv")

data1 = df['mpg'].values
data2 = df['weight'].values


# calculate covariance matrix
covariance = cov(data1, data2)

# calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)

# plot
plt.scatter(data1, data2)
plt.show()

# summarize
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data2), std(data2)))
print('Covariance: %.3f' % covariance[0][1])
print('Pearsons correlation: %.3f' % corr)
# Out:
# data1: mean=23.515 stdv=7.806
# data2: mean=2970.425 stdv=845.777
# Covariance: -5505.212
# Pearsons correlation: -0.832

# %% [markdown]
# a strong negative Pearson's correlation between "mpg" and "weight" indicates that as the weight of vehicles increases, their fuel efficiency (mpg) tends to decrease.

# %%
data1 = df['mpg'].values
data3 = df['displacement'].values


# calculate covariance matrix
covariance = cov(data1, data3)

# calculate Pearson's correlation
corr, _ = pearsonr(data1, data3)

# plot
plt.scatter(data1, data3)
plt.show()

# summarize
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data3), std(data3)))
print('Covariance: %.3f' % covariance[0][1])
print('Pearsons correlation: %.3f' % corr)
# Out:
# data1: mean=23.515 stdv=7.806
# data2: mean=193.426 stdv=104.139
# Covariance: -655.402
# Pearsons correlation: -0.804

# %% [markdown]
# It's expected that vehicles with larger engine displacement (bigger engines) would generally consume more fuel, leading to a lower mpg. Thus, we might anticipate a negative correlation between these two variables.
