# %% [markdown]
# ## Calculating cost with gradient descent and learning rate
# - Change the iteration and learning rate vaules and see the impact on cost.
# - Low iteration values with high learning rate (i.e. big steps) may lead to miss the global minimum
# - Goal is to reach minimum cost with minimum iteration

# %% [markdown]
# ![cost_function.png](attachment:cost_function.png)

# %%
# code credit:codebasics https://codebasics.io/coming-soon

import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 100       #change value
    n = len(x)
    learning_rate = 0.08   #change value

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %%
def modified_gradient_descent(x, y, iterations=100, learning_rate=0.08):
    m_curr = b_curr = 0
    n = len(x)
    mse_results = []

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        mse = (1/n) * sum([val**2 for val in (y-y_predicted)])
        mse_results.append(mse)
        
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd

    return mse_results

# Data
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])


# Compute MSE results for both 100 and 200 iterations
mse_results_100 = modified_gradient_descent(x, y, iterations=100)
mse_results_200 = modified_gradient_descent(x, y, iterations=200)

# Checking the first few values to ensure the lists are populated correctly
mse_results_100[:5], mse_results_200[:5]

# Invoking the modified_gradient_descent function
mse_results = modified_gradient_descent(x, y)

# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(mse_results_100, label='100 Iterations', color='blue')
plt.plot(mse_results_200[:100], label='First 100 of 200 Iterations', color='red', linestyle='--')
plt.title('Mean Squared Error (MSE) vs. Iterations')
plt.xlabel('Iterations')
plt.ylabel('MSE')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Compute MSE results for different learning rates
mse_results_lr_01 = modified_gradient_descent(x, y, iterations=100, learning_rate=0.01)
mse_results_lr_08 = modified_gradient_descent(x, y, iterations=100, learning_rate=0.08)
mse_results_lr_05 = modified_gradient_descent(x, y, iterations=100, learning_rate=0.5)

# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(mse_results_lr_01, label='Learning Rate 0.01', color='green')
plt.plot(mse_results_lr_08, label='Learning Rate 0.08', color='blue')
plt.plot(mse_results_lr_05, label='Learning Rate 0.5', color='red')
plt.title('Mean Squared Error (MSE) vs. Iterations for Different Learning Rates')
plt.xlabel('Iterations')
plt.ylabel('MSE')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting the results using subplots for clearer visualization
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

# Plot for Learning Rate 0.01
axes[0].plot(mse_results_lr_01, color='green')
axes[0].set_title('Learning Rate 0.01')
axes[0].set_xlabel('Iterations')
axes[0].set_ylabel('MSE')
axes[0].grid(True)

# Plot for Learning Rate 0.08
axes[1].plot(mse_results_lr_08, color='blue')
axes[1].set_title('Learning Rate 0.08')
axes[1].set_xlabel('Iterations')
axes[1].set_ylabel('MSE')
axes[1].grid(True)

# Plot for Learning Rate 0.5
axes[2].plot(mse_results_lr_05, color='red')
axes[2].set_title('Learning Rate 0.5')
axes[2].set_xlabel('Iterations')
axes[2].set_ylabel('MSE')
axes[2].grid(True)

plt.tight_layout()
plt.show()
